# %% [markdown]
# Purpose: get most common genres from GoodReads API (defined by user tags) from a set of book IDs

# %%
import pandas as pd
import numpy as np 

import requests
import xml.etree.ElementTree as ET

import time
import glob

# %%
# API credentials
f = open("goodreads_key.txt", "r")
api_key = f.read()
f.close()

# %%
# import list of books with IDs
ratings_df = pd.read_csv('books.csv')

# filter for only books in sub-sample for which we already collected images
ls_raw = glob.glob('imgs/*.jpg')
ls = [int(i.split('\\')[-1].split('.')[0]) for i in ls_raw]

ratings_df = ratings_df[ratings_df['bookID'].isin(ls)]

ratings_df.shape
# Out:
# (994, 12)

# %%
# remove tags that aren't actually genres
genreExceptions = [
'to-read', 'currently-reading', 'owned', 'default', 'favorites', 'books-i-own',
'ebook', 'kindle', 'library', 'audiobook', 'owned-books', 'audiobooks', 'my-books',
'ebooks', 'to-buy', 'english', 'calibre', 'books', 'british', 'audio', 'my-library',
'favourites', 're-read', 'general', 'e-books'
]
# h/t https://www.goodreads.com/topic/show/19317219-getting-the-genre-of-a-book

# %%
def get_root(book_id):
    r_url = 'https://www.goodreads.com/book/show/'+str(book_id)+'.xml?key='+api_key
    root = ET.fromstring(requests.get(r_url).content)
    return root

# %%
def get_genres(root, genreExceptions):
    
    book_genres = []
    for child in root.iter('shelf'): 
        book_genres.append(child.attrib['name'])
    
    book_genres = [i for i in book_genres if i not in genreExceptions]
    book_genres = book_genres[:5]
    return book_genres

# %%
# iterate through list of books: 
# %%time

id_list = list(ratings_df['bookID']) 
genres_list = list()

for i in id_list:
    root = get_root(i)
    genres = get_genres(root, genreExceptions)
    genres_list.append(genres)
    
    # limit rate
    time.sleep(1)
    
genre_df = pd.DataFrame({'bookID': id_list, 'genres': genres_list})
# Out:
# Wall time: 27min 30s

# %%
ratings_df.merge(genre_df, how='left', on='bookID').to_csv('books_genres_sample.csv', index=False)

# %%
ratings_df.merge(genre_df, how='left', on='bookID')
# Out:
#      bookID                                              title  \
# 0        35  The Lord of the Rings (The Lord of the Rings  ...
# 1        37   The Lord of the Rings: Complete Visual Companion
# 2        59                                 The Changeling Sea
# 3        72             Artesia: Adventures in the Known World
# 4        81                                 Giving Good Weight
# 5        83                             Rising from the Plains
# 6        94            Getting Results with Curriculum Mapping
# 7       180                                   Wrinkles in Time
# 8       204          The Long Shadow (The Morland Dynasty  #6)
# 9       205         A Long Shadow (Inspector Ian Rutledge  #8)
# 10      208        A Shadow in Summer (Long Price Quartet  #1)
# 11      216                      Miami Blues (Hoke Moseley #1)
# 12      289  The Beloved: Reflections on the Path of the Heart
# 13      333                                     The Zebra Wall
# 14      350                         Stranger in a Strange Land
# 15      409                                    Against the Day
# 16      413                                      Mason & Dixon
# 17      428                                 Play It As It Lays
# 18      453                                The Music of Chance
# 19      539     Lovely in Her Bones (Elizabeth MacPherson  #2)
# 20      597      Killing Yourself to Live: 85% of a True Story
# 21      656                                      War and Peace
# 22      698                                 Digging to America
# 23      824                                         The Cobweb
# 24      828                                          Interface
# 25      864                                      The Alchemist
# 26      866  Fullmetal Alchemist  Vol. 9 (Fullmetal Alchemi...
# 27      871  Fullmetal Alchemist  Vol. 4 (Fullmetal Alchemi...
# 28      888                           The Last Days of Pompeii
# 29      929                                Memoirs of a Geisha
# ..      ...                                                ...
# 964   44086                               Maps for Lost Lovers
# 973                                      Emma Donoghue            3.50
# 974                    Dashka Slater/Nicoletta Ceccoli            3.60
# 975                          David Sedaris/Amy Sedaris            4.09
# 976                                  Robert Bringhurst            4.24
# 977                                       Maxine Swann            3.20
# 978                                    Charles Petzold            4.39
# 979                                      Robert  Evans            3.92
# 980                                   Gordon Dahlquist            3.50
# 981                                       Randall Hyde            3.92
# 982                                    Minette Walters            3.95
# 983                                         Roald Dahl            4.41
# 984                                          Betty Jay            3.56
# 985                                  Peter F. Hamilton            4.30
# 986           Haruki Murakami/Jay Rubin/Philip Gabriel            3.84
# 987              Nancy MacDonell Smith/Nancy MacDonell            3.43
# 988                                        Paul Auster            3.89
# 989                                     Philip Pullman            4.26
# 990                           Roald Dahl/Horacio Elena            4.05
# 991        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            4.03
# 992        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            4.09
# 993                                William T. Vollmann            3.96
#
#            isbn        isbn13 language_code    num_pages  ratings_count  \
# 0     618260587  9.780620e+12         en-US         1216           1618
# 1     618510826  9.780620e+12           eng          224            359
# 2     141312629  9.780140e+12           eng          137           4454
# 3    1932386106  9.781930e+12           eng          352             52
# 4     374516006  9.780370e+12           eng          288            542
# 5     374520658  9.780370e+12           eng          208           1341
# 6     871209993  9.780870e+12           eng          192             55
# 7     380720442  9.780380e+12           eng          360           1035
# 8     751506435  9.780750e+12           eng          367            376
# 9    006078671X  9.780060e+12           eng          352           3086
# 10    765313405  9.780770e+12           eng          331           9852
# 11   1400032466  9.781400e+12           eng          191           2897
# 12   014019553X  9.780140e+12           eng          102            328
# 13     60733039  9.780060e+12           eng          147            217
# 14    441788386  9.780440e+12           eng          528         251872
# 15   159420120X  9.781590e+12           eng         1085           5296
# 16    312423209  9.780310e+12           eng          773           8086
# 17    374529949  9.780370e+12           eng          231          23656
# 18    140154078  9.780140e+12         en-US          217            361
# 19    345360354  9.780350e+12           eng          224           1371
# 20    743264460  9.780740e+12           eng          245          26381
# 21    192833987  9.780190e+12           eng         1392         211671
# 22    307263940  9.780310e+12           eng          277          17155
# 23    553383442  9.780550e+12           eng          448           2465
# 24    553383434  9.780550e+12           eng          640           4731
# 25     60887966  9.780060e+12           eng          192            920
# 26   142150460X  9.781420e+12           eng          192           9013
# 27   1591169291  9.781590e+12           eng          200          10752
# 28   158715739X  9.781590e+12           eng          360           1156
# 29   1400096898  9.781400e+12           eng          503         280309
# ..          ...           ...           ...          ...            ...
# 964  1400076978  9.781400e+12           eng          400           2127
# 965  1401201938  9.781400e+12           eng          144           1709
# 966   143037277  9.780140e+12         en-US          154            406
# 967  1590170431  9.781590e+12           eng          244           1780
# 968   156028476  9.780160e+12           eng          144            370
# 969   802141447  9.780800e+12         en-GB          400           4239
# 970  1560258500  9.781560e+12           eng          282           9808
# 971   830819711  9.780830e+12         en-US          191           9632
# 972    64407721  9.780060e+12           eng          228           6097
# 973   156032643  9.780160e+12           eng          672           1883
# 974   618554599  9.780620e+12         en-US           32             89
# 975  1586212230  9.781590e+12         en-US            3            308
# 976   881792063  9.780880e+12         en-US          352           7564
# 977   312288018  9.780310e+12           eng          240            207
# 978   735611319  9.780740e+12           eng          400           4919
# 979   571219314  9.780570e+12           eng          462           2209
# 980   385340354  9.780390e+12         en-US          760           3678
# 981  1593270038  9.781590e+12           eng          456            145
# 982   312956126  9.780310e+12           eng          384           7019
# 983    61214965  9.780060e+12         en-US            4            199
# 984  184046027X  9.781840e+12         en-GB          176            108
# 985   446605166  9.780450e+12           eng          572           4092
# 986  1400096081  9.781400e+12           eng          362           1162
# 987   142003565  9.780140e+12         en-US          224            109
# 988   140097368  9.780140e+12         en-US          192             62
# 989   375947221  9.780380e+12           eng          944             70
# 990  9681907191  9.789680e+12           spa           96            174
# 991  9722332201  9.789720e+12           por          149            211
# 992  9722331329  9.789720e+12           por          176            161
# 993   140131965  9.780140e+12           eng          415            820
#
#      text_reviews_count publication_date                      publisher  \
# 0                   140        10/1/2002      Houghton Mifflin Harcourt
# 1                     6       11/15/2004      Houghton Mifflin Harcourt
# 2                   302        4/14/2003                       Firebird
# 3                     4       12/14/2005                        Archaia
# 4                    36         4/1/1994      Farrar  Straus and Giroux
# 5                    98        11/1/1987      Farrar  Straus and Giroux
# 6                     5       11/15/2004                           ASCD
# 7                    23        10/1/1994               Harper Perennial
# 8                    17         6/1/1994       Little  Brown Book Group
# 9                   237         1/3/2006                 William Morrow
# 10                  633         3/7/2006                      Tor Books
# 11                  178        8/10/2004     Vintage Crime/Black Lizard
# 12                   16         1/1/1998                  Penguin Books
# 13                   24        2/15/2005              Greenwillow Books
# 14                 6241        10/1/1991                            Ace
# 15                  587       11/21/2006                  Penguin Press
# 16                  602         1/3/2004                    Picador USA
# 17                 1706       11/15/2005      Farrar  Straus and Giroux
# 18                   36        12/1/1991                  Penguin Books
# 19                   43        5/13/1990               Ballantine Books
# 20                 1109        6/13/2006                       Scribner
# 21                 6245        6/25/1998        Oxford University Press
# 22                 1841         5/2/2006                Alfred A. Knopf
# 23                  137        5/31/2005                  Spectra Books
# 24                  270        5/31/2005                        Spectra
# 25                   76         5/2/2006                      HarperOne
# 26                  153        9/19/2006                  VIZ Media LLC
# 27                  294        11/8/2005                  VIZ Media LLC
# 28                   68        12/3/2002                    Borgo Press
# 29                 3703       11/22/2005              Vintage Books USA
# ..                  ...              ...                            ...
# 964                 277         5/9/2006                        Vintage
# 965                  88         3/1/2004                      DC Comics
# 966                  45        7/25/2006                  Penguin Books
# 967                 220        8/31/2003                  NYRB Classics
# 968                  26        6/16/2003                  Mariner Books
# 969                 350        6/29/2004                    Grove Press
# 970                 497        3/24/2006            Running Press Adult
# 971                 212         4/1/1998             InterVarsity Press
# 972                 592        2/27/1999                     HarperTeen
# 973                 185         9/5/2005                  Mariner Books
# 974                  17        10/2/2006    HMH Books for Young Readers
# 975                  62        10/1/2001       Grand Central Publishing
# 976                 206        9/27/2004     Hartley & Marks Publishers
# 977                  28        12/1/2004                    Picador USA
# 978                 418       10/21/2000                Microsoft Press
# 979                 176        2/19/2004                  Faber & Faber
# 980                 459       12/15/2006                   Bantam Books
# 981                  12        11/8/2004                No Starch Press
# 982                 113       10/15/1995             St. Martin's Press
# 983                  36        2/20/2007       HarperCollins Publishers
# 984                   6        8/16/2003             Palgrave Macmillan
# 985                  39         8/1/1997                         Aspect
# 986                 132         9/1/2007                        Vintage
# 987                  14       10/28/2003                  Penguin Books
# 988                   3         1/5/1988                  Penguin Books
# 989                   9        4/10/2007  Knopf Books for Young Readers
# 990                  20         6/1/2000             Alfaguara Infantil
